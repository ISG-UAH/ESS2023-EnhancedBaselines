# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
in_days = 4
lead = 4
elasticnet_file = f'results/elasticnetAR_predictions_{in_days}_{lead}.txt'
svr_file = f'results/SVR_predictions_{in_days}_{lead}.txt'

data_file = 'data/omni_1hr_clean.csv'

# %%
elasticnet_pred = pd.read_csv(elasticnet_file, index_col=0, parse_dates=[1]).set_index('Timestamp')
svr_pred = pd.read_csv(svr_file, index_col=0, parse_dates=[1]).set_index('Timestamp')
elasticnet_pred, svr_pred
# Out:
# (                               Prediction
#  Timestamp
#  2017-01-01 00:00:00   [372.4145031879098]
#  2017-01-01 01:00:00  [373.77986929011524]
#  2017-01-01 02:00:00   [373.0906591588879]
#  2017-01-01 03:00:00   [373.2941394832521]
#  2017-01-01 04:00:00   [375.1778332169538]
#  ...                                   ...
#  2017-12-31 19:00:00   [426.0773091238175]
#  2017-12-31 20:00:00  [427.51674361172303]
#  2017-12-31 21:00:00   [430.1725932197547]
#  2017-12-31 22:00:00  [430.07145814065433]
#  2017-12-31 23:00:00  [429.67509328070275]
#
#  [8760 rows x 1 columns],
#                                 Prediction
#  Timestamp
#  2017-01-01 00:00:00   [364.8129791673235]
#  2017-01-01 01:00:00  [364.51039294812244]
#  2017-01-01 02:00:00   [364.1928877287749]
#  2017-01-01 03:00:00   [363.8728672640745]
#  2017-01-01 04:00:00   [363.6678351432192]
#  ...                                   ...
#  2017-12-31 19:00:00  [395.32853033142777]
#  2017-12-31 20:00:00    [396.455577322177]
#  2017-12-31 21:00:00  [397.59949498498514]
#  2017-12-31 22:00:00  [398.66263758604015]
#  2017-12-31 23:00:00   [399.7463243047248]
#
#  [8760 rows x 1 columns])

# %%
elasticnet_pred['V'] = elasticnet_pred['Prediction'].apply(lambda x: eval(x)[0])
svr_pred['V'] = svr_pred['Prediction'].apply(lambda x: eval(x)[0])
elasticnet_pred, svr_pred
# Out:
# (                               Prediction           V
#  Timestamp
#  2017-01-01 00:00:00   [372.4145031879098]  372.414503
#  2017-01-01 01:00:00  [373.77986929011524]  373.779869
#  2017-01-01 02:00:00   [373.0906591588879]  373.090659
#  2017-01-01 03:00:00   [373.2941394832521]  373.294139
#  2017-01-01 04:00:00   [375.1778332169538]  375.177833
#  ...                                   ...         ...
#  2017-12-31 19:00:00   [426.0773091238175]  426.077309
#  2017-12-31 20:00:00  [427.51674361172303]  427.516744
#  2017-12-31 21:00:00   [430.1725932197547]  430.172593
#  2017-12-31 22:00:00  [430.07145814065433]  430.071458
#  2017-12-31 23:00:00  [429.67509328070275]  429.675093
#
#  [8760 rows x 2 columns],
#                                 Prediction           V
#  Timestamp
#  2017-01-01 00:00:00   [364.8129791673235]  364.812979
#  2017-01-01 01:00:00  [364.51039294812244]  364.510393
#  2017-01-01 02:00:00   [364.1928877287749]  364.192888
#  2017-01-01 03:00:00   [363.8728672640745]  363.872867
#  2017-01-01 04:00:00   [363.6678351432192]  363.667835
#  ...                                   ...         ...
#  2017-12-31 19:00:00  [395.32853033142777]  395.328530
#  2017-12-31 20:00:00    [396.455577322177]  396.455577
#  2017-12-31 21:00:00  [397.59949498498514]  397.599495
#  2017-12-31 22:00:00  [398.66263758604015]  398.662638
#  2017-12-31 23:00:00   [399.7463243047248]  399.746324
#
#  [8760 rows x 2 columns])

# %%
observations = pd.read_csv(data_file, index_col = 0, parse_dates=[0]).interpolate(method='time')
observations
# Out:
#                       BR   BT   BN      V    N         T
# datetime
# 1996-08-01 00:00:00  1.5 -3.7 -3.3  498.0  3.3  143535.0
# 1996-08-01 01:00:00  5.1 -1.2 -0.7  492.0  2.7  121473.0
# 1996-08-01 02:00:00  3.2 -2.7  3.9  513.0  3.6  163789.0
# 1996-08-01 03:00:00  1.1 -2.1 -1.8  538.0  4.2  159645.0
# 1996-08-01 04:00:00  2.4 -3.0  1.9  539.0  4.5  199876.0
# ...                  ...  ...  ...    ...  ...       ...
# 2021-12-31 20:00:00 -0.6 -2.0  4.2  418.0  7.8   78906.0
# 2021-12-31 21:00:00 -1.3 -2.4  3.4  423.0  8.6   88405.0
# 2021-12-31 22:00:00  1.1 -2.3  1.6  414.0  8.1   95631.0
# 2021-12-31 23:00:00  4.6 -2.8 -3.8  388.0  5.0   68545.0
# 2022-01-01 00:00:00  5.6 -2.6 -4.3  389.0  5.4   76351.0
#
# [222817 rows x 6 columns]

# %%
shift_n_days = observations.shift(freq=f'{lead}d')
shift_n_days
# Out:
#                       BR   BT   BN      V    N         T
# datetime
# 1996-08-05 00:00:00  1.5 -3.7 -3.3  498.0  3.3  143535.0
# 1996-08-05 01:00:00  5.1 -1.2 -0.7  492.0  2.7  121473.0
# 1996-08-05 02:00:00  3.2 -2.7  3.9  513.0  3.6  163789.0
# 1996-08-05 03:00:00  1.1 -2.1 -1.8  538.0  4.2  159645.0
# 1996-08-05 04:00:00  2.4 -3.0  1.9  539.0  4.5  199876.0
# ...                  ...  ...  ...    ...  ...       ...
# 2022-01-04 20:00:00 -0.6 -2.0  4.2  418.0  7.8   78906.0
# 2022-01-04 21:00:00 -1.3 -2.4  3.4  423.0  8.6   88405.0
# 2022-01-04 22:00:00  1.1 -2.3  1.6  414.0  8.1   95631.0
# 2022-01-04 23:00:00  4.6 -2.8 -3.8  388.0  5.0   68545.0
# 2022-01-05 00:00:00  5.6 -2.6 -4.3  389.0  5.4   76351.0
#
# [222817 rows x 6 columns]

# %%
shift_27_days = observations.shift(freq='27d')
shift_27_days
# Out:
#                       BR   BT   BN      V    N         T
# datetime
# 1996-08-28 00:00:00  1.5 -3.7 -3.3  498.0  3.3  143535.0
# 1996-08-28 01:00:00  5.1 -1.2 -0.7  492.0  2.7  121473.0
# 1996-08-28 02:00:00  3.2 -2.7  3.9  513.0  3.6  163789.0
# 1996-08-28 03:00:00  1.1 -2.1 -1.8  538.0  4.2  159645.0
# 1996-08-28 04:00:00  2.4 -3.0  1.9  539.0  4.5  199876.0
# ...                  ...  ...  ...    ...  ...       ...
# 2022-01-27 20:00:00 -0.6 -2.0  4.2  418.0  7.8   78906.0
# 2022-01-27 21:00:00 -1.3 -2.4  3.4  423.0  8.6   88405.0
# 2022-01-27 22:00:00  1.1 -2.3  1.6  414.0  8.1   95631.0
# 2022-01-27 23:00:00  4.6 -2.8 -3.8  388.0  5.0   68545.0
# 2022-01-28 00:00:00  5.6 -2.6 -4.3  389.0  5.4   76351.0
#
# [222817 rows x 6 columns]

# %%
plottable = observations.join(shift_n_days, 
                 rsuffix=f'_{lead}d').join(shift_27_days,
                                          rsuffix='_27d').join(elasticnet_pred, 
                  rsuffix='_elasticnet').dropna()[['V',
                                                                        f'V_{lead}d',
                                                                        'V_27d',
                                                                        'V_elasticnet']]

# %%
plottable = plottable.loc['2017-10-04':'2017-10-10']

plt.figure(figsize=(6.5, 5))
idx = plottable.index
styles = ['-', ':', '-.', '--', '--']
markers = ['*', '^', 'x', '.']

xlabel = 'Date'
legend = ['Observation', '4 days (RMSE = $154.25$ km$\cdot$s$^{-1}$)', 
          '27 days (RMSE = $104.98$ km$\cdot$s$^{-1}$)', 
          'ElasticNet AR (RMSE = $92.58$ km$\cdot$s$^{-1}$)', 'SVR']

for i in range(len(plottable.columns)):
    if i > 3:
        plt.plot(idx, plottable[plottable.columns[i]], linestyle=styles[i],
                marker=markers[i-2])
    else:
        plt.plot(idx, plottable[plottable.columns[i]], linestyle=styles[i])

plt.xlabel(xlabel)
plt.ylabel('Bulk speed (km/s)')
plt.legend(legend)
plt.xticks(rotation=45)

# plottable.loc['2017-10-01':'2017-10-31'].plot(figsize=(5, 5), style=['-',
#                                       ':',
#                                       '-.',
#                                       '--',
#                                       '--'],
#                                     xlabel='Date',
#                                              marker='.');
# Out:
# (array([17443., 17444., 17445., 17446., 17447., 17448., 17449., 17450.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
